# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filepath1 = "Clean_2015.csv"
filepath2 = "Clean_2016.csv"
filepath3 = "Clean_2017.csv"
filepath4 = "Clean_2018.csv"
filepath5 = "Clean_2019.csv"
filepath6 = "Clean_2020.csv"

df_2015 = pd.read_csv(filepath1)
df_2016 = pd.read_csv(filepath2)
df_2017 = pd.read_csv(filepath3)
df_2018 = pd.read_csv(filepath4)
df_2019 = pd.read_csv(filepath5)
df_2020 = pd.read_csv(filepath6)

df_2015.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629
#
#    Social Support  Health Life Expectancy  Freedom  Generosity  \
# 0         1.34951                 0.94143  0.66557     0.29678
# 1         1.40223                 0.94784  0.62877     0.43630
# 2         1.36058                 0.87464  0.64938     0.34139
# 3         1.33095                 0.88521  0.66973     0.34699
# 4         1.32261                 0.90563  0.63297     0.45811
#
#    Trust (Government Corruption)
# 0                        0.41978
# 1                        0.14145
# 2                        0.48357
# ...

# %%
df_combo = pd.merge(df_2015, df_2016, how="outer", on="Country", suffixes=["_2015", "_2016"]).reset_index(drop=True)
df_combo
# Out:
#                Country  Happiness Rank_2015  Happiness Score_2015  \
# 0          Switzerland                  1.0                 7.587
# 1              Iceland                  2.0                 7.561
# 2              Denmark                  3.0                 7.527
# 3               Norway                  4.0                 7.522
# 4               Canada                  5.0                 7.427
# ..                 ...                  ...                   ...
# 159             Belize                  NaN                   NaN
# 160            Somalia                  NaN                   NaN
# 161  Somaliland Region                  NaN                   NaN
# 162            Namibia                  NaN                   NaN
# 163        South Sudan                  NaN                   NaN
#
#      Economy (GDP per Capita)_2015  Social Support_2015  \
# 0                          1.39651              1.34951
# 1                          1.30232              1.40223
# ...

# %%
df_2017.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Social Support', 'Health Life Expectancy',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')

# %%
df_combo.columns
# Out:
# Index(['Country', 'Happiness Rank_2015', 'Happiness Score_2015',
#        'Economy (GDP per Capita)_2015', 'Social Support_2015',
#        'Health Life Expectancy_2015', 'Freedom_2015', 'Generosity_2015',
#        'Trust (Government Corruption)_2015', 'Happiness Rank_2016',
#        'Happiness Score_2016', 'Economy (GDP per Capita)_2016',
#        'Social Support_2016', 'Health Life Expectancy_2016', 'Freedom_2016',
#        'Trust (Government Corruption)_2016', 'Generosity_2016'],
#       dtype='object')

# %%
df_combo = pd.merge(df_combo, df_2017, how="outer", on="Country").rename(columns={"Happiness Rank": "Happiness Rank_2017", "Happiness Score":"Happiness Score_2017", "Economy (GDP per Capita)": "Economy (GDP per Capita)_2017", 
                                                                                 "Social Support": "Social Support_2017", "Health Life Expectancy": "Health Life Expectancy_2017", "Freedom": "Freedom_2017", "Trust (Government Corruption)": "Trust (Government Corruption)_2017", "Generosity": "Generosity_2017"})
df_combo
# Out:
#                       Country  Happiness Rank_2015  Happiness Score_2015  \
# 0                 Switzerland                  1.0                 7.587
# 1                     Iceland                  2.0                 7.561
# 2                     Denmark                  3.0                 7.527
# 3                      Norway                  4.0                 7.522
# 4                      Canada                  5.0                 7.427
# ..                        ...                  ...                   ...
# 161         Somaliland Region                  NaN                   NaN
# 162                   Namibia                  NaN                   NaN
# 163               South Sudan                  NaN                   NaN
# 164  Taiwan Province of China                  NaN                   NaN
# 165   Hong Kong S.A.R., China                  NaN                   NaN
#
#      Economy (GDP per Capita)_2015  Social Support_2015  \
# ...

# %%
df_2018.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Social Support', 'Health Life Expectancy',
#        'Freedom', 'Generosity', 'Trust (Government Corruption)'],
#       dtype='object')

# %%
df_combo = pd.merge(df_combo, df_2018, how="outer", on="Country").rename(columns={"Happiness Rank": "Happiness Rank_2018", "Happiness Score":"Happiness Score_2018", "Economy (GDP per Capita)": "Economy (GDP per Capita)_2018", 
                                                                                 "Social Support": "Social Support_2018", "Health Life Expectancy": "Health Life Expectancy_2018", "Freedom": "Freedom_2018", "Trust (Government Corruption)": "Trust (Government Corruption)_2018", "Generosity": "Generosity_2018"})
df_combo
# Out:
#                       Country  Happiness Rank_2015  Happiness Score_2015  \
# 0                 Switzerland                  1.0                 7.587
# 1                     Iceland                  2.0                 7.561
# 2                     Denmark                  3.0                 7.527
# 3                      Norway                  4.0                 7.522
# 4                      Canada                  5.0                 7.427
# ..                        ...                  ...                   ...
# 163               South Sudan                  NaN                   NaN
# 164  Taiwan Province of China                  NaN                   NaN
# 165   Hong Kong S.A.R., China                  NaN                   NaN
# 166         Trinidad & Tobago                  NaN                   NaN
# 167           Northern Cyprus                  NaN                   NaN
#
#      Economy (GDP per Capita)_2015  Social Support_2015  \
# ...

# %%
df_combo = pd.merge(df_combo, df_2019, how="outer", on="Country").rename(columns={"Happiness Rank": "Happiness Rank_2019", "Happiness Score":"Happiness Score_2019", "Economy (GDP per Capita)": "Economy (GDP per Capita)_2019", 
                                                                                 "Social Support": "Social Support_2019", "Health Life Expectancy": "Health Life Expectancy_2019", "Freedom": "Freedom_2019", "Trust (Government Corruption)": "Trust (Government Corruption)_2019", "Generosity": "Generosity_2019"})
df_combo
# Out:
#                      Country  Happiness Rank_2015  Happiness Score_2015  \
# 0                Switzerland                  1.0                 7.587
# 1                    Iceland                  2.0                 7.561
# 2                    Denmark                  3.0                 7.527
# 3                     Norway                  4.0                 7.522
# 4                     Canada                  5.0                 7.427
# ..                       ...                  ...                   ...
# 165  Hong Kong S.A.R., China                  NaN                   NaN
# 166        Trinidad & Tobago                  NaN                   NaN
# 167          Northern Cyprus                  NaN                   NaN
# 168          North Macedonia                  NaN                   NaN
# 169                   Gambia                  NaN                   NaN
#
#      Economy (GDP per Capita)_2015  Social Support_2015  \
# ...

# %%
df_combo = pd.merge(df_combo, df_2020, how="outer", on="Country").rename(columns={"Happiness Rank": "Happiness Rank_2020", "Happiness Score":"Happiness Score_2020", "Economy (GDP per Capita)": "Economy (GDP per Capita)_2020", 
                                                                                 "Social Support": "Social Support_2020", "Health Life Expectancy": "Health Life Expectancy_2020", "Freedom": "Freedom_2020", "Trust (Government Corruption)": "Trust (Government Corruption)_2020", "Generosity": "Generosity_2020"})
df_combo
# Out:
#                        Country  Happiness Rank_2015  Happiness Score_2015  \
# 0                  Switzerland                  1.0                 7.587
# 1                      Iceland                  2.0                 7.561
# 2                      Denmark                  3.0                 7.527
# 3                       Norway                  4.0                 7.522
# 4                       Canada                  5.0                 7.427
# ..                         ...                  ...                   ...
# 167            Northern Cyprus                  NaN                   NaN
# 168            North Macedonia                  NaN                   NaN
# 169                     Gambia                  NaN                   NaN
# 170  Hong Kong S.A.R. of China                  NaN                   NaN
# 171                   Maldives                  NaN                   NaN
#
#      Economy (GDP per Capita)_2015  Social Support_2015  \
# ...

# %%
sorted(df_combo.columns)
# Out:
# ['Country',
#  'Economy (GDP per Capita)_2015',
#  'Economy (GDP per Capita)_2016',
#  'Economy (GDP per Capita)_2017',
#  'Economy (GDP per Capita)_2018',
#  'Economy (GDP per Capita)_2019',
#  'Economy (GDP per Capita)_2020',
#  'Freedom_2015',
#  'Freedom_2016',
#  'Freedom_2017',
#  'Freedom_2018',
#  'Freedom_2019',
#  'Freedom_2020',
#  'Generosity_2015',
#  'Generosity_2016',
#  'Generosity_2017',
#  'Generosity_2018',
#  'Generosity_2019',
#  'Generosity_2020',
#  'Happiness Rank_2015',
#  'Happiness Rank_2016',
#  'Happiness Rank_2017',
#  'Happiness Rank_2018',
#  'Happiness Rank_2019',
#  'Happiness Rank_2020',
#  'Happiness Score_2015',
#  'Happiness Score_2016',
#  'Happiness Score_2017',
#  'Happiness Score_2018',
#  'Happiness Score_2019',
#  'Happiness Score_2020',
#  'Health Life Expectancy_2015',
#  'Health Life Expectancy_2016',
#  'Health Life Expectancy_2017',
#  'Health Life Expectancy_2018',
#  'Health Life Expectancy_2019',
#  'Health Life Expectancy_2020',
# ...

# %%
cols=[x for x in df_combo.columns if "Happiness Score" in x]
cols.append("Country")
print(cols)
# Out:
# ['Happiness Score_2015', 'Happiness Score_2016', 'Happiness Score_2017', 'Happiness Score_2018', 'Happiness Score_2019', 'Happiness Score_2020', 'Country']

# %%
df_sub = df_combo.loc[:,cols][0:5]
df_sub
# Out:
#    Happiness Score_2015  Happiness Score_2016  Happiness Score_2017  \
# 0                 7.587                 7.509                 7.494
# 1                 7.561                 7.501                 7.504
# 2                 7.527                 7.526                 7.522
# 3                 7.522                 7.498                 7.537
# 4                 7.427                 7.404                 7.316
#
#    Happiness Score_2018  Happiness Score_2019  Happiness Score_2020  \
# 0                 7.487                 7.480                   NaN
# 1                 7.495                 7.494                   NaN
# 2                 7.555                 7.600                   NaN
# 3                 7.594                 7.554                   NaN
# 4                 7.328                 7.278                   NaN
#
#        Country
# 0  Switzerland
# 1      Iceland
# 2      Denmark
# 3       Norway
# 4       Canada

# %%
df_sub.set_index("Country").plot(kind="line")
# x year
# lines are countries

# %%
df_sub.T
# Out:
#                                 0        1        2       3       4
# Happiness Score_2015        7.587    7.561    7.527   7.522   7.427
# Happiness Score_2016        7.509    7.501    7.526   7.498   7.404
# Happiness Score_2017        7.494    7.504    7.522   7.537   7.316
# Happiness Score_2018        7.487    7.495    7.555   7.594   7.328
# Happiness Score_2019         7.48    7.494      7.6   7.554   7.278
# Happiness Score_2020          NaN      NaN      NaN     NaN     NaN
# Country               Switzerland  Iceland  Denmark  Norway  Canada

# %%
df_combo.to_csv("Horizontal_Merge.csv")
