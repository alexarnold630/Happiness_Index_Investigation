# %% [markdown]
# ## Line chart for the top 3 countries over the 5 years, iceland, denmark, norway
# #####

# %%
# data science imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# linear modelling
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
import scipy.stats as sts

# %%
filepath1 = "Vertical_Merge.csv"
df = pd.read_csv(filepath1)

# %%
df.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629
#
#    Social Support  Health Life Expectancy  Freedom  \
# 0         1.34951                 0.94143  0.66557
# 1         1.40223                 0.94784  0.62877
# 2         1.36058                 0.87464  0.64938
# 3         1.33095                 0.88521  0.66973
# 4         1.32261                 0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Year
# 0                        0.41978     0.29678  2015
# 1                        0.14145     0.43630  2015
# 2                        0.48357     0.34139  2015
# ...

# %%
df["Happiness Rank"].max()
# Out:
# 158

# %%
topdf = df.loc[df["Happiness Rank"] <= 5]
topdf.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629
#
#    Social Support  Health Life Expectancy  Freedom  \
# 0         1.34951                 0.94143  0.66557
# 1         1.40223                 0.94784  0.62877
# 2         1.36058                 0.87464  0.64938
# 3         1.33095                 0.88521  0.66973
# 4         1.32261                 0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Year
# 0                        0.41978     0.29678  2015
# 1                        0.14145     0.43630  2015
# 2                        0.48357     0.34139  2015
# ...

# %% [markdown]
# ## Bottom 3 countries

# %%
bottomdf = df.loc[df["Happiness Rank"] >= 138]
bottomdf["Country"].value_counts()
# Out:
# Tanzania                    6
# Afghanistan                 6
# Burundi                     6
# Rwanda                      6
# Syria                       5
# Togo                        5
# Madagascar                  5
# Yemen                       5
# Central African Republic    5
# South Sudan                 5
# Botswana                    4
# Haiti                       4
# Guinea                      4
# Liberia                     4
# Zimbabwe                    4
# Lesotho                     4
# Angola                      3
# Comoros                     3
# Malawi                      3
# Benin                       3
# Chad                        2
# Cambodia                    2
# India                       2
# Burkina Faso                2
# Uganda                      2
# Niger                       2
# Ivory Coast                 2
# Zambia                      2
# Gabon                       1
# Sierra Leone                1
# Senegal                     1
# ...

# %%
rwanda = bottomdf.loc[bottomdf["Country"]=="Rwanda"]
rwanda
# Out:
#     Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 153  Rwanda             154           3.4650                  0.222080
# 309  Rwanda             152           3.5150                  0.328460
# 465  Rwanda             151           3.4710                  0.368746
# 620  Rwanda             151           3.4080                  0.332000
# 777  Rwanda             152           3.3340                  0.359000
# 931  Rwanda             150           3.3123                  0.760010
#
#      Social Support  Health Life Expectancy   Freedom  \
# 153        0.773700                0.428640  0.592010
# 309        0.615860                0.318650  0.543200
# 465        0.945707                0.326425  0.581844
# 620        0.896000                0.400000  0.636000
# 777        0.711000                0.614000  0.555000
# 931        0.540835                0.610988  0.900589
#
#      Trust (Government Corruption)  Generosity  Year
# ...

# %%
afghanistan = bottomdf.loc[bottomdf["Country"]=="Afghanistan"]
afghanistan
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 152  Afghanistan             153           3.5750                  0.319820
# 311  Afghanistan             154           3.3600                  0.382270
# 455  Afghanistan             141           3.7940                  0.401477
# 614  Afghanistan             145           3.6320                  0.332000
# 779  Afghanistan             154           3.2030                  0.350000
# 934  Afghanistan             153           2.5669                  0.746286
#
#      Social Support  Health Life Expectancy   Freedom  \
# 152        0.302850                0.303350  0.234140
# 311        0.110370                0.173440  0.164300
# 455        0.581543                0.180747  0.106180
# 614        0.537000                0.255000  0.085000
# 779        0.517000                0.361000  0.000000
# 934        0.470367                0.525900  0.396573
#
# ...

# %%
tanzania = bottomdf.loc[bottomdf["Country"]=="Tanzania"]
tanzania
# Out:
#       Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 145  Tanzania             146           3.7810                  0.285200
# 306  Tanzania             149           3.6660                  0.471550
# 467  Tanzania             153           3.3490                  0.511136
# 622  Tanzania             153           3.3030                  0.455000
# 778  Tanzania             153           3.2310                  0.476000
# 929  Tanzania             148           3.4762                  0.796767
#
#      Social Support  Health Life Expectancy   Freedom  \
# 145        1.002680                0.382150  0.328780
# 306        0.776230                0.357000  0.317600
# 467        1.041990                0.364509  0.390018
# 622        0.991000                0.381000  0.481000
# 778        0.885000                0.499000  0.417000
# 929        0.688933                0.574961  0.821540
#
#      Trust (Government Corruption)  Generosity  Year
# ...

# %%
years = rwanda.Year

# %%
rwandaHV = rwanda["Happiness Score"].values
afghanHV = afghanistan["Happiness Score"].values
tanzaniaHV = tanzania["Happiness Score"].values

# %%
plt.figure(figsize=(10,6))

plt.plot(years, rwandaHV,color="#a0c4ff",label="Rwanda", linewidth=3)

plt.plot(years, afghanHV, color="#9bf6ff", label="Afghanistan", linewidth=3)

plt.plot(years, tanzaniaHV ,color="#bdb2ff", label="Tanzania", linewidth=3)

plt.legend()
plt.title("Bottom 3 Countries Happiness Score over the Years")
plt.xlabel("Years")
plt.ylabel("Happiness Score")
plt.grid(True)
plt.show()

# %%
rwandaEV = rwanda["Economy (GDP per Capita)"].values
afghanEV = afghanistan["Economy (GDP per Capita)"].values
tanzaniaEV = tanzania["Economy (GDP per Capita)"].values

# %%
plt.figure(figsize=(10,6))

plt.plot(years, rwandaEV,color="#a0c4ff",label="Rwanda", linewidth=3)

plt.plot(years, afghanEV, color="#9bf6ff", label="Afghanistan", linewidth=3)

plt.plot(years, tanzaniaEV ,color="#bdb2ff", label="Tanzania", linewidth=3)

plt.legend()
plt.title("Bottom 3 Countries Economy (GDP per Capita) over the Years")
plt.xlabel("Years")
plt.ylabel("Economy (GDP per Capita)")
plt.grid(True)
plt.show()

# %%
rwandaSV = rwanda["Social Support"].values
afghanSV = afghanistan["Social Support"].values
tanzaniaSV = tanzania["Social Support"].values

# %%
plt.figure(figsize=(10,6))

plt.plot(years, rwandaSV,color="#a0c4ff",label="Rwanda", linewidth=3)

plt.plot(years, afghanSV, color="#9bf6ff", label="Afghanistan", linewidth=3)

plt.plot(years, tanzaniaSV ,color="#bdb2ff", label="Tanzania", linewidth=3)

plt.legend()
plt.title("Bottom 3 Countries Social Support over the Years")
plt.xlabel("Years")
plt.ylabel("Social Support")
plt.grid(True)
plt.show()

# %%
rwandaLV = rwanda["Health Life Expectancy"].values
afghanLV = afghanistan["Health Life Expectancy"].values
tanzaniaLV = tanzania["Health Life Expectancy"].values

# %%
plt.figure(figsize=(10,6))

plt.plot(years, rwandaLV,color="#a0c4ff",label="Rwanda", linewidth=3)

plt.plot(years, afghanLV, color="#9bf6ff", label="Afghanistan", linewidth=3)

plt.plot(years, tanzaniaLV ,color="#bdb2ff", label="Tanzania", linewidth=3)

plt.legend()
plt.title("Bottom 3 Countries Health Life Expectancy over the Years")
plt.xlabel("Years")
plt.ylabel("Health Life Expectancy")
plt.grid(True)
plt.show()

# %%
rwandaFV = rwanda["Freedom"].values
afghanFV = afghanistan["Freedom"].values
tanzaniaFV = tanzania["Freedom"].values

# %%
plt.figure(figsize=(10,6))

plt.plot(years, rwandaFV,color="#a0c4ff",label="Rwanda", linewidth=3)

plt.plot(years, afghanFV, color="#9bf6ff", label="Afghanistan", linewidth=3)

plt.plot(years, tanzaniaFV ,color="#bdb2ff", label="Tanzania", linewidth=3)

plt.legend()
plt.title("Bottom 3 Countries Freedom over the Years")
plt.xlabel("Years")
plt.ylabel("Freedom")
plt.grid(True)
plt.show()

# %%
rwandaTV= rwanda["Trust (Government Corruption)"].values
afghanTV = afghanistan["Trust (Government Corruption)"].values
tanzaniaTV = tanzania["Trust (Government Corruption)"].values

# %%
plt.figure(figsize=(10,6))

plt.plot(years, rwandaTV,color="#a0c4ff",label="Rwanda", linewidth=3)

plt.plot(years, afghanTV, color="#9bf6ff", label="Afghanistan", linewidth=3)

plt.plot(years, tanzaniaTV ,color="#bdb2ff", label="Tanzania", linewidth=3) 
         
plt.legend()
plt.title("Bottom 3 Countries Trust (Government Corruption) over the Years")
plt.xlabel("Years")
plt.ylabel("Trust (Government Corruption)")
plt.grid(True)
plt.show()

# %%
rwandavGV = rwanda["Generosity"].values
afghanGV = afghanistan["Generosity"].values
tanzaniaGV = tanzania["Generosity"].values

# %%
plt.figure(figsize=(10,6))

plt.plot(years, rwandavGV,color="#a0c4ff",label="Rwanda", linewidth=3)

plt.plot(years, afghanGV, color="#9bf6ff", label="Afghanistan", linewidth=3)

plt.plot(years, tanzaniaGV ,color="#bdb2ff", label="Tanzania", linewidth=3)

plt.legend()
plt.title("Bottom 3 Countries Generosity over the Years")
plt.xlabel("Years")
plt.ylabel("Generosity")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Top 3 Countries

# %%
iceland = topdf.loc[topdf["Country"]=="Iceland"]
iceland
# Out:
#      Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 1    Iceland               2           7.5610                  1.302320
# 160  Iceland               3           7.5010                  1.426660
# 317  Iceland               3           7.5040                  1.480633
# 473  Iceland               4           7.4950                  1.343000
# 629  Iceland               4           7.4940                  1.380000
# 785  Iceland               4           7.5045                  1.077256
#
#      Social Support  Health Life Expectancy   Freedom  \
# 1          1.402230                0.947840  0.628770
# 160        1.183260                0.867330  0.566240
# 317        1.610574                0.833552  0.627163
# 473        1.644000                0.914000  0.677000
# 629        1.624000                1.026000  0.591000
# 785        0.974670                0.730000  0.948892
#
#      Trust (Government Corruption)  Generosity  Year
# ...

# %%
icevalues = iceland["Happiness Score"].values

# %%
norway = topdf.loc[topdf["Country"]=="Norway"]
norway
# Out:
#     Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 3    Norway               4            7.522                  1.459000
# 161  Norway               4            7.498                  1.577440
# 315  Norway               1            7.537                  1.616463
# 471  Norway               2            7.594                  1.456000
# 628  Norway               3            7.554                  1.488000
# 786  Norway               5            7.488                  1.108780
#
#      Social Support  Health Life Expectancy   Freedom  \
# 3          1.330950                0.885210  0.669730
# 161        1.126900                0.795790  0.596090
# 315        1.533524                0.796667  0.635423
# 471        1.582000                0.861000  0.686000
# 628        1.582000                1.028000  0.603000
# 786        0.952487                0.732008  0.955750
#
#      Trust (Government Corruption)  Generosity  Year
# ...

# %%
denmark = topdf.loc[topdf["Country"]=="Denmark"]
denmark
# Out:
#      Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 2    Denmark               3           7.5270                  1.325480
# 158  Denmark               1           7.5260                  1.441780
# 316  Denmark               2           7.5220                  1.482383
# 472  Denmark               3           7.5550                  1.351000
# 627  Denmark               2           7.6000                  1.383000
# 783  Denmark               2           7.6456                  1.077400
#
#      Social Support  Health Life Expectancy   Freedom  \
# 2          1.360580                0.874640  0.649380
# 158        1.163740                0.795040  0.579410
# 316        1.551122                0.792566  0.626007
# 472        1.590000                0.868000  0.683000
# 627        1.573000                0.996000  0.592000
# 783        0.955991                0.724025  0.951444
#
#      Trust (Government Corruption)  Generosity  Year
# ...

# %%
years = denmark.Year

# %%
denHV = denmark["Happiness Score"].values
norHV = norway["Happiness Score"].values
iceHV = iceland["Happiness Score"].values

# %%
plt.figure(figsize=(10,6))

plt.plot(years, denHV,color="#FFC6FF",label="Denmark", linewidth=3)

plt.plot(years, norHV,color="#ffd6a5",label="Norway", linewidth=3)

plt.plot(years,iceHV,color="#ffadad", label="Iceland", linewidth=3)

plt.legend()
plt.title("Top 3 Countries Happiness Score over the Years")
plt.xlabel("Years")
plt.ylabel("Happiness Score")
plt.grid(True)
plt.show()

# %%
denEV = denmark["Economy (GDP per Capita)"].values
norEV = norway["Economy (GDP per Capita)"].values
iceEV = iceland["Economy (GDP per Capita)"].values

# %%
plt.figure(figsize=(10,6))

plt.plot(years, denEV,color="#FFC6FF",label="Denmark", linewidth=3)

plt.plot(years, norEV,color="#ffd6a5",label="Norway", linewidth=3)

plt.plot(years,iceEV,color="#ffadad", label="Iceland", linewidth=3)

plt.legend()
plt.title("Top 3 Countries Economy (GDP per Capita) over the Years")
plt.xlabel("Years")
plt.ylabel("Economy (GDP per Capita)")
plt.grid(True)
plt.show()

# %%
denSV = denmark["Social Support"].values
norSV = norway["Social Support"].values
iceSV = iceland["Social Support"].values

# %%
plt.figure(figsize=(10,6))

plt.plot(years, denSV,color="#FFC6FF",label="Denmark", linewidth=3)

plt.plot(years, norSV,color="#ffd6a5",label="Norway", linewidth=3)

plt.plot(years, iceSV,color="#ffadad", label="Iceland", linewidth=3)

plt.legend()
plt.title("Top 3 Countries Social Support over the Years")
plt.xlabel("Years")
plt.ylabel("Social Support")
plt.grid(True)
plt.show()

# %%
denLV = denmark["Health Life Expectancy"].values
norLV = norway["Health Life Expectancy"].values
iceLV = iceland["Health Life Expectancy"].values

# %%
plt.figure(figsize=(10,6))

plt.plot(years, denLV,color="#FFC6FF",label="Denmark", linewidth=3)

plt.plot(years, norLV,color="#ffd6a5",label="Norway", linewidth=3)

plt.plot(years, iceLV,color="#ffadad", label="Iceland", linewidth=3)

plt.legend()
plt.title("Top 3 Countries Health Life Expectancy over the Years")
plt.xlabel("Years")
plt.ylabel("Health Life Expectancy")
plt.grid(True)
plt.show()

# %%
denFV = denmark["Freedom"].values
norFV = norway["Freedom"].values
iceFV = iceland["Freedom"].values

# %%
plt.figure(figsize=(10,6))

plt.plot(years, denFV,color="#FFC6FF",label="Denmark", linewidth=3)

plt.plot(years, norFV,color="#ffd6a5",label="Norway", linewidth=3)

plt.plot(years, iceFV,color="#ffadad", label="Iceland", linewidth=3)

plt.legend()
plt.title("Top 3 Countries Freedom over the Years")
plt.xlabel("Years")
plt.ylabel("Freedom")
plt.grid(True)
plt.show()

# %%
denTV= denmark["Trust (Government Corruption)"].values
norTV = norway["Trust (Government Corruption)"].values
iceTV = iceland["Trust (Government Corruption)"].values

# %%
plt.figure(figsize=(10,6))

plt.plot(years, denTV,color="#FFC6FF",label="Denmark", linewidth=3)

plt.plot(years, norTV,color="#ffd6a5",label="Norway", linewidth=3)

plt.plot(years, iceTV,color="#ffadad", label="Iceland", linewidth=3)

plt.legend()
plt.title("Top 3 Countries Trust (Government Corruption) over the Years")
plt.xlabel("Years")
plt.ylabel("Trust (Government Corruption)")
plt.grid(True)
plt.show()

# %%
denGV = denmark["Generosity"].values
norGV = norway["Generosity"].values
iceGV = iceland["Generosity"].values

# %%
plt.figure(figsize=(10,6))

plt.plot(years, denGV,color="#FFC6FF",label="Denmark", linewidth=3)

plt.plot(years, norGV,color="#ffd6a5",label="Norway", linewidth=3)

plt.plot(years, iceGV,color="#ffadad", label="Iceland", linewidth=3)

plt.legend()
plt.title("Top 3 Countries Generosity over the Years")
plt.xlabel("Years")
plt.ylabel("Generosity")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(years, denHV,color="#FFC6FF",label="Denmark", linewidth=3)

plt.plot(years, norHV,color="#ffd6a5",label="Norway", linewidth=3)

plt.plot(years,iceHV,color="#ffadad", label="Iceland", linewidth=3)

plt.plot(years, rwandaHV,color="#a0c4ff",label="Rwanda", linewidth=3)

plt.plot(years, afghanHV, color="#9bf6ff", label="Afghanistan", linewidth=3)

plt.plot(years, tanzaniaHV ,color="#bdb2ff", label="Tanzania", linewidth=3)

plt.legend()
plt.title("Top and Bottom 3 Countries Happiness Score over the Years")
plt.xlabel("Years")
plt.ylabel("Happiness Score")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(years, rwandaEV,color="#a0c4ff",label="Rwanda", linewidth=3)

plt.plot(years, afghanEV, color="#9bf6ff", label="Afghanistan", linewidth=3)

plt.plot(years, tanzaniaEV ,color="#bdb2ff", label="Tanzania", linewidth=3)

plt.plot(years, denEV,color="#FFC6FF",label="Denmark", linewidth=3)

plt.plot(years, norEV,color="#ffd6a5",label="Norway", linewidth=3)

plt.plot(years,iceEV,color="#ffadad", label="Iceland", linewidth=3)

plt.legend()
plt.title("Top and Bottom 3 Countries Economy (GDP per Capita) over the Years")
plt.xlabel("Years")
plt.ylabel("Economy (GDP per Capita)")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(years, rwandaSV,color="#a0c4ff",label="Rwanda", linewidth=3)

plt.plot(years, afghanSV, color="#9bf6ff", label="Afghanistan", linewidth=3)

plt.plot(years, tanzaniaSV ,color="#bdb2ff", label="Tanzania", linewidth=3)

plt.plot(years, denSV,color="#FFC6FF",label="Denmark", linewidth=3)

plt.plot(years, norSV,color="#ffd6a5",label="Norway", linewidth=3)

plt.plot(years, iceSV,color="#ffadad", label="Iceland", linewidth=3)

plt.legend()
plt.title("Top and Bottom 3 Countries Social Support over the Years")
plt.xlabel("Years")
plt.ylabel("Social Support")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(years, rwandaLV,color="#a0c4ff",label="Rwanda", linewidth=3)

plt.plot(years, afghanLV, color="#9bf6ff", label="Afghanistan", linewidth=3)

plt.plot(years, tanzaniaLV, color="#bdb2ff", label="Tanzania", linewidth=3)

plt.plot(years, denLV,color="#FFC6FF",label="Denmark", linewidth=3)

plt.plot(years, norLV,color="#ffd6a5",label="Norway", linewidth=3)

plt.plot(years, iceLV,color="#ffadad", label="Iceland", linewidth=3)

plt.legend()
plt.title("Top and Bottom 3 Countries Health Life Expectancy over the Years")
plt.xlabel("Years")
plt.ylabel("Health Life Expectancy")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(years, rwandaFV,color="#a0c4ff",label="Rwanda", linewidth=3)

plt.plot(years, afghanFV, color="#9bf6ff", label="Afghanistan", linewidth=3)

plt.plot(years, tanzaniaFV ,color="#bdb2ff", label="Tanzania", linewidth=3)

plt.plot(years, denFV,color="#FFC6FF",label="Denmark", linewidth=3)

plt.plot(years, norFV,color="#ffd6a5",label="Norway", linewidth=3)

plt.plot(years, iceFV,color="#ffadad", label="Iceland", linewidth=3)

plt.legend()
plt.title("Top and Bottom 3 Countries Freedom over the Years")
plt.xlabel("Years")
plt.ylabel("Freedom")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(years, rwandaTV,color="#a0c4ff",label="Rwanda", linewidth=3)

plt.plot(years, afghanTV, color="#9bf6ff", label="Afghanistan", linewidth=3)

plt.plot(years, tanzaniaTV ,color="#bdb2ff", label="Tanzania", linewidth=3) 

plt.plot(years, denTV,color="#FFC6FF",label="Denmark", linewidth=3)

plt.plot(years, norTV,color="#ffd6a5",label="Norway", linewidth=3)

plt.plot(years, iceTV,color="#ffadad", label="Iceland", linewidth=3)

plt.legend()
plt.title("Top and Bottom 3 Countries Trust (Government Corruption) over the Years")
plt.xlabel("Years")
plt.ylabel("Trust (Government Corruption)")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(years, rwandavGV,color="#a0c4ff",label="Rwanda", linewidth=3)

plt.plot(years, afghanGV, color="#9bf6ff", label="Afghanistan", linewidth=3)

plt.plot(years, tanzaniaGV ,color="#bdb2ff", label="Tanzania", linewidth=3)

plt.plot(years, denGV,color="#FFC6FF",label="Denmark", linewidth=3)

plt.plot(years, norGV,color="#ffd6a5",label="Norway", linewidth=3)

plt.plot(years, iceGV,color="#ffadad", label="Iceland", linewidth=3)

plt.legend()
plt.title("Top and Bottom 3 Countries Generosity over the Years")
plt.xlabel("Years")
plt.ylabel("Generosity")
plt.grid(True)
plt.show()
